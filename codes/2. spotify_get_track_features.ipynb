# %% [markdown]
# ### Extracción de datos desde API de Spotify

# %% [markdown]
# Crear un archivo config.py en el que se guarden las siguientes credenciales: CLIENT_ID y CLIENT_SECRET.

# %%
import requests
import base64
from config import CLIENT_ID, CLIENT_SECRET

client_id = CLIENT_ID
client_secret = CLIENT_SECRET

# Codificar las credenciales en base64
credentials = base64.b64encode(f"{client_id}:{client_secret}".encode()).decode("utf-8")

# Hacer la solicitud para obtener el token
url = "https://accounts.spotify.com/api/token"
headers = {
    "Authorization": f"Basic {credentials}"
}
data = {
    "grant_type": "client_credentials"
}

response = requests.post(url, headers=headers, data=data)
token = response.json().get("access_token")

print(f"Token de acceso: {token}")
# Out:
# Token de acceso: BQBWWxOlMwsTR2OstVJ5YN4eoCvP38HdAaXOcmkX2a57wI3aMUfcIH7LM_ixgLadHnMlz5_VFXJOdSwUe04n1daYu49rpOIfckY_ZukgnRR0Fk1e3Do

# %% [markdown]
# Leer de la base de datos SQL Server la data extraída en la primera parte.

# %%
import pyodbc
import pandas as pd
import requests
from config import SERVER, DATABASE

conn_str = (
    r'DRIVER={SQL Server};'
    rf'SERVER={SERVER};' 
    rf'DATABASE={DATABASE};'
    r'Trusted_Connection=yes;'
)
conn = pyodbc.connect(conn_str)
cursor = conn.cursor()

# Leer los datos de la tabla Track
cursor.execute("SELECT Nombre_Artista, Nombre_Album, Nombre_Track, ID, Duration_ms, Explicit, Artists, Track_Number FROM Track")
tracks = cursor.fetchall()

# %%
tracks
# Out:
# [('Shakira', 'Las Mujeres Ya No Lloran', 'Puntería', '2dYXrWkNO40NXy2Q3IYLRc', 181666, False, 'Shakira, Cardi B', 1),
#  ('Shakira', 'Las Mujeres Ya No Lloran', 'La Fuerte', '09mHLXMh3rmruStxevfh3U', 164833, False, 'Shakira, Bizarrap', 2),
#  ('Shakira', 'Las Mujeres Ya No Lloran', 'Tiempo Sin Verte', '6c8jkAgbVk44B8SwRi8vQs', 196233, False, 'Shakira', 3),
#  ('Shakira', 'Las Mujeres Ya No Lloran', 'Cohete', '5JKk6Gh5CLlwpbPz48eWtB', 172503, False, 'Shakira, Rauw Alejandro', 4),
#  ('Shakira', 'Las Mujeres Ya No Lloran', '(Entre Paréntesis)', '68viiGZoRbLCjsy5xD4VrU', 168896, False, 'Shakira, Grupo Frontera', 5),
#  ('Shakira', 'Las Mujeres Ya No Lloran', 'Cómo Dónde y Cuándo', '40Ccxt7rKCXiViGQKPPACR', 179000, False, 'Shakira', 6),
#  ('Shakira', 'Las Mujeres Ya No Lloran', 'Nassau', '2D48pEtMZRYcByAhjvVLM3', 156466, False, 'Shakira', 7),
#  ('Shakira', 'Las Mujeres Ya No Lloran', 'Última', '3FEIMzqeq5EXqaMi3mHP6L', 178666, False, 'Shakira', 8),
#  ('Shakira', 'Las Mujeres Ya No Lloran', 'Te Felicito', '64zcAZeIWHszCGKOSqAogH', 172533, False, 'Shakira, Rauw Alejandro', 9),
#  ('Shakira', 'Las Mujeres Ya No Lloran', 'Monotonía', '2dfH1gA3FZDv9L69Dqy9RY', 161633, False, 'Shakira, Ozuna', 10),
#  ('Shakira', 'Las Mujeres Ya No Lloran', 'Shakira: Bzrp Music Sessions, Vol. 53', '3MhdQkxCOkM41Q7oPFIABJ', 217133, False, 'Bizarrap, Shakira', 11),
#  ('Shakira', 'Las Mujeres Ya No Lloran', 'TQG', '1VyoUKGlVrGE9QvCT0Cw0b', 199066, True, 'KAROL G, Shakira', 12),
#  ('Shakira', 'Las Mujeres Ya No Lloran', 'Acróstico - Milan + Sasha', '2qcLLzq1deFSABxoqWFGdi', 171674, False, 'Shakira', 13),
#  ('Shakira', 'Las Mujeres Ya No Lloran', 'Copa Vacía', '3KV9n8QMepWCXI3TkWKeZy', 174525, False, 'Shakira, Manuel Turizo', 14),
#  ('Shakira', 'Las Mujeres Ya No Lloran', 'El Jefe', '3cLJZEdlBiY2jZ5lduO4Sm', 170600, True, 'Shakira, Fuerza Regida', 15),
#  ('Shakira', 'Las Mujeres Ya No Lloran', 'Bzrp Music Sessions, Vol. 53 - Tiësto Remix', '22Q0eVNpSUIWG0prN6cVmI', 216099, False, 'Bizarrap, Shakira', 16),
#  ('Shakira', 'Las Mujeres Ya No Lloran', 'Puntería - Vinyl Version', '1DYtDpkadSjqvjjtIP88SI', 189066, False, 'Shakira, Cardi B', 17),
#  ('Shakira', 'El Dorado', 'Me Enamoré', '4qknM1pQz53QOyfDVTjcM9', 226893, False, 'Shakira', 1),
#  ('Shakira', 'El Dorado', 'Nada', '1D8bmUIhLHEO4KMS2SHwUx', 189573, False, 'Shakira', 2),
#  ('Shakira', 'El Dorado', 'Chantaje (feat. Maluma)', '6mICuAdrwEjh6Y6lroV2Kg', 195840, False, 'Shakira, Maluma', 3),
#  ('Shakira', 'El Dorado', 'When a Woman', '6MFVCPU3QN3YqMjJz4mtFe', 198106, False, 'Shakira', 4),
#  ('Shakira', 'El Dorado', 'Amarillo', '5Qn56ssVeZJfNwDCme7Eo0', 219640, False, 'Shakira', 5),
#  ('Shakira', 'El Dorado', 'Perro Fiel (feat. Nicky Jam)', '70lnL3QaSOIIyMa2X9aVRL', 195213, False, 'Shakira, Nicky Jam', 6),
#  ('Shakira', 'El Dorado', 'Trap (feat. Maluma)', '7GncL3nyKUjsEm8Z5gvTpW', 199813, False, 'Shakira, Maluma', 7),
#  ('Shakira', 'El Dorado', 'Comme moi (feat. Shakira)', '2RHpEALdmp9dnPuEm7SLKB', 188453, False, 'Black M, Shakira', 8),
#  ('Shakira', 'El Dorado', 'Coconut Tree', '4uGz0wWAkH4FGPpBR6eaHt', 230173, False, 'Shakira', 9),
#  ('Shakira', 'El Dorado', 'La Bicicleta', '0sXvAOmXgjR2QUqLK1MltU', 227706, False, 'Carlos Vives, Shakira', 10),
#  ('Shakira', 'El Dorado', 'Deja vu', '5clmffOxeckeJ2e3GMy6UZ', 196466, False, 'Prince Royce, Shakira', 11),
#  ('Shakira', 'El Dorado', 'What We Said (feat. MAGIC!) - Comme moi English Version', '0kM7Geaz7x7r17CPONjpOU', 179480, False, 'Shakira, MAGIC!', 12),
#  ('Shakira', 'El Dorado', 'Toneladas', '5VD3oQilL00HfIEW6ICSQq', 191586, False, 'Shakira', 13),
#  ('Shakira', 'Shakira. (Expanded Edition)', 'Dare (La La La)', '0YoUczWJPqphLvxnTXG00N', 186506, False, 'Shakira', 1),
#  ('Shakira', 'Shakira. (Expanded Edition)', "Can't Remember to Forget You (feat. Rihanna)", '2Sh4sAOfnSHEVKFyysxzat', 206866, False, 'Shakira, Rihanna', 2),
#  ('Shakira', 'Shakira. (Expanded Edition)', 'Empire', '1eIk4CkooTRycHSDfaShLC', 239333, False, 'Shakira', 3),
#  ('Shakira', 'Shakira. (Expanded Edition)', "You Don't Care About Me", '27w1b6BqVy6ygGH2xC57ym', 221533, False, 'Shakira', 4),
#  ('Shakira', 'Shakira. (Expanded Edition)', 'Cut Me Deep (feat. MAGIC!)', '6x2P4rSizcNieZOHuOR6VX', 195800, False, 'Shakira, MAGIC!', 5),
#  ('Shakira', 'Shakira. (Expanded Edition)', 'Spotlight', '3bLV6IzouYNz0r6yWbJdB6', 203266, False, 'Shakira', 6),
#  ('Shakira', 'Shakira. (Expanded Edition)', 'Broken Record', '3oUkORJUX7gzhzqakqVQQM', 194533, False, 'Shakira', 7),
#  ('Shakira', 'Shakira. (Expanded Edition)', 'Medicine (feat. Blake Shelton)', '54Htj557TgF5BB3pmVyrcH', 198106, False, 'Shakira, Blake Shelton', 8),
#  ('Shakira', 'Shakira. (Expanded Edition)', '23', '1pMkyQhAIAUN5fBNunIkGA', 239786, False, 'Shakira', 9),
#  ('Shakira', 'Shakira. (Expanded Edition)', 'The One Thing', '3FeclOAkmIFucOCAeTRbn8', 192013, False, 'Shakira', 10),
#  ('Shakira', 'Shakira. (Expanded Edition)', 'Nunca Me Acuerdo de Olvidarte', '0Hb4KV0zjIuW4J3ZckBsOH', 206466, False, 'Shakira', 11),
#  ('Shakira', 'Shakira. (Expanded Edition)', 'Loca por Ti', '4mzObs1phLpRl7Xrggmi2o', 221746, False, 'Shakira', 12),
#  ('Shakira', 'Shakira. (Expanded Edition)', 'La La La', '0F6thtSISbps8VCdF6dhSk', 186333, False, 'Shakira', 13),
#  ('Shakira', 'Shakira. (Expanded Edition)', 'Chasing Shadows', '0dUHP7KmAPrcU7n7O4m5ZT', 211400, False, 'Shakira', 14),
#  ('Shakira', 'Shakira. (Expanded Edition)', 'That Way', '6LsYSp8cjEysnQwzQy9Pbf', 188626, False, 'Shakira', 15),
#  ('Shakira', 'Sale el Sol', 'Sale el Sol', '1DJxR9NMQ14fv1WK0pHodt', 200133, False, 'Shakira', 1),
#  ('Shakira', 'Sale el Sol', 'Loca (feat. El Cata)', '42k1KeBehAd83lrGt1okiC', 183693, False, 'Shakira, El Cata', 2),
#  ('Shakira', 'Sale el Sol', 'Antes de las Seis', '5J5uyhoBZxJwmjy2Zg6DgF', 174533, False, 'Shakira', 3),
#  ('Shakira', 'Sale el Sol', 'Gordita (feat. Residente Calle 13)', '6fufW0yhOYcNHvAaUwgpS1', 204986, False, 'Shakira, Calle 13', 4),
#  ('Shakira', 'Sale el Sol', 'Addicted to You', '4zy1s9GnxWsNzZp1688euA', 147480, False, 'Shakira', 5),
#  ('Shakira', 'Sale el Sol', 'Lo Que Más', '6c8ZIkGXlKE5vSzrUbHLDr', 146973, False, 'Shakira', 6),
#  ('Shakira', 'Sale el Sol', 'Mariposas', '5mqbIuIagl2q2HZqTiLSfS', 227293, False, 'Shakira', 7),
#  ('Shakira', 'Sale el Sol', 'Rabiosa (feat. El Cata)', '19t0Z7qsoV6A1CGJVYRnjm', 170386, False, 'Shakira, El Cata', 8),
#  ('Shakira', 'Sale el Sol', 'Devoción', '58haa2vmqz7tCG7FFDrLWZ', 209573, False, 'Shakira', 9),
#  ('Shakira', 'Sale el Sol', 'Islands', '7kHU3Re5YQd45PLwGRbGvE', 162893, False, 'Shakira', 10),
#  ('Shakira', 'Sale el Sol', 'Tu Boca', '6ja9N12lzBD1TRuQfZb18z', 205813, False, 'Shakira', 11),
#  ('Shakira', 'Sale el Sol', 'Waka Waka (Esto Es Africa) - K-Mix', '4DRFIoachXrW8YV7Yje0yz', 184120, False, 'Shakira', 12),
#  ('Shakira', 'Sale el Sol', 'Loca (feat. Dizzee Rascal)', '6YMPu36VGIknb8Ey1ohW3j', 193160, False, 'Shakira, Dizzee Rascal', 13),
#  ('Shakira', 'Sale el Sol', 'Rabiosa (feat. Pitbull)', '2Xh7dyCHCErCv3PmdVEGw4', 170600, False, 'Shakira, Pitbull', 14),
#  ('Shakira', 'Sale el Sol', 'Waka Waka (This Time for Africa) - K-Mix', '63Tl9k1sH8tznn3bqoMuyF', 183946, False, 'Shakira', 15),
#  ('Shakira', 'Sale el Sol', 'Loca (feat. Dizzee Rascal) - Freemasons Radio Edit', '2Sk7RnSVAQGcTovlJQ5FD1', 181400, False, 'Shakira, Dizzee Rascal, Freemasons', 16),
#  ('Shakira', 'She Wolf (Expanded Edition)', 'She Wolf', '4cS2HQ6jK80vqdY9ofpztx', 188866, False, 'Shakira', 1),
#  ('Shakira', 'She Wolf (Expanded Edition)', 'Did It Again', '3RaqIAipLoQLVVNm41IMnJ', 192706, False, 'Shakira', 2),
#  ('Shakira', 'She Wolf (Expanded Edition)', 'Long Time', '0fWiBdVFTGjTQHa5nAlwqi', 176133, False, 'Shakira', 3),
#  ('Shakira', 'She Wolf (Expanded Edition)', 'Why Wait', '2f3tjFRhnE2rJfnLwWfxCe', 221240, False, 'Shakira', 4),
#  ('Shakira', 'She Wolf (Expanded Edition)', 'Good Stuff', '6QAr8cDN1WdkfMm07b5lnf', 197173, False, 'Shakira', 5),
#  ('Shakira', 'She Wolf (Expanded Edition)', 'Men in This Town', '5z2BEa0LHhiOlqEWitESMn', 214160, False, 'Shakira', 6),
#  ('Shakira', 'She Wolf (Expanded Edition)', 'Gypsy', '3FESsHW8mAuiIsYpK6aJ6u', 198826, False, 'Shakira', 7),
#  ('Shakira', 'She Wolf (Expanded Edition)', 'Spy (feat. Wyclef Jean)', '5c8vdQdRggwDspd3MNgjZX', 207133, False, 'Shakira, Wyclef Jean', 8),
#  ('Shakira', 'She Wolf (Expanded Edition)', 'Mon Amour', '4ZY1MKm7pbC2v19Lj02SSR', 245066, False, 'Shakira', 9),
#  ('Shakira', 'She Wolf (Expanded Edition)', 'Loba', '1fPCGREltHJuV3axEPydLp', 189200, False, 'Shakira', 10),
#  ('Shakira', 'She Wolf (Expanded Edition)', 'Lo Hecho Está Hecho', '2ZLkmFeraZyt2ccuwnupny', 192693, False, 'Shakira', 11),
#  ('Shakira', 'She Wolf (Expanded Edition)', 'Años Luz', '7ikBuouzgk31Z03FQBD5TN', 221400, False, 'Shakira', 12),
#  ('Shakira', 'She Wolf (Expanded Edition)', 'Give It Up To Me (feat. Lil Wayne)', '5lR4YDKdhJUkGUYMrMRx43', 183573, False, 'Shakira, Lil Wayne', 13),
#  ('Shakira', 'She Wolf (Expanded Edition)', 'Did It Again (feat. Kid Cudi)', '6AoGe1Zp6WNpPTvNC6Ehca', 227333, False, 'Shakira, Kid Cudi', 14),
#  ('Shakira', 'She Wolf (Expanded Edition)', 'Gypsy - Live From T4 Studios', '7lAD6W07EfSkEs9nHENFi5', 208040, False, 'Shakira', 15),
#  ('Shakira', 'She Wolf (Expanded Edition)', 'She Wolf - Live From T4 Studios', '4QTPXntU1GPF932cw62ocq', 189666, False, 'Shakira', 16),
#  ('Shakira', 'Oral Fixation, Vol. 2 (Expanded Edition)', 'How Do You Do', '6YDBAZHIcOEo1rSrcca7rJ', 225426, False, 'Shakira', 1),
#  ('Shakira', 'Oral Fixation, Vol. 2 (Expanded Edition)', 'Illegal (feat. Carlos Santana)', '4O1xKPHOH7iXlzMNUDuxHS', 233200, False, 'Shakira, Carlos Santana', 2),
#  ('Shakira', 'Oral Fixation, Vol. 2 (Expanded Edition)', "Hips Don't Lie (feat. Wyclef Jean)", '3ZFTkvIE7kyPt6Nu3PEa7V', 218093, False, 'Shakira, Wyclef Jean', 3),
#  ('Shakira', 'Oral Fixation, Vol. 2 (Expanded Edition)', 'Animal City', '4NirETfurhjh8U9Y1l5U1S', 195506, False, 'Shakira', 4),
#  ('Shakira', 'Oral Fixation, Vol. 2 (Expanded Edition)', "Don't Bother", '433JymbpWnRMHXzp1oTRP7', 257026, False, 'Shakira', 5),
#  ('Shakira', 'Oral Fixation, Vol. 2 (Expanded Edition)', 'The Day and the Time (feat. Gustavo Cerati)', '080gSRai7pWpGO8WsWk1Ww', 262466, False, 'Shakira, Gustavo Cerati', 6),
#  ('Shakira', 'Oral Fixation, Vol. 2 (Expanded Edition)', 'Dreams for Plans', '4ng0dNET7TNV2RMjVB65m6', 242760, False, 'Shakira', 7),
#  ('Shakira', 'Oral Fixation, Vol. 2 (Expanded Edition)', 'Hey You', '4DOamGN0O3Z7mRP8EVTw4f', 249960, False, 'Shakira', 8),
#  ('Shakira', 'Oral Fixation, Vol. 2 (Expanded Edition)', 'Your Embrace', '42JOtajDAVadoj1x84l2Wg', 212973, False, 'Shakira', 9),
#  ('Shakira', 'Oral Fixation, Vol. 2 (Expanded Edition)', 'Costume Makes the Clown', '6IkZCUzTNVdBpIixdippHA', 192133, False, 'Shakira', 10),
#  ('Shakira', 'Oral Fixation, Vol. 2 (Expanded Edition)', 'Something', '4lbUTqZIk42k2R6upLKAu6', 261733, False, 'Shakira', 11),
#  ('Shakira', 'Oral Fixation, Vol. 2 (Expanded Edition)', 'Timor', '0RoXTnhkLvbUR4dSsY3O0f', 212440, False, 'Shakira', 12),
#  ('Shakira', 'Oral Fixation, Vol. 2 (Expanded Edition)', 'La Tortura (feat. Alejandro Sanz) - Alternate Version', '6UwBdW2wlO9ikUD3LU8GF3', 213440, False, 'Shakira, Alejandro Sanz', 13),
#  ('Shakira', 'Fijación Oral, Vol. 1', 'En Tus Pupilas', '28x1syDlcQU3QOFhYIG63K', 261866, False, 'Shakira', 1),
#  ('Shakira', 'Fijación Oral, Vol. 1', 'La Pared', '3TZNOCoBeIeMMTAkyMJUxq', 199173, False, 'Shakira', 2),
#  ('Shakira', 'Fijación Oral, Vol. 1', 'La Tortura (feat. Alejandro Sanz)', '5BSclXJTa9B0iURhUjZo50', 212893, False, 'Shakira, Alejandro Sanz', 3),
#  ('Shakira', 'Fijación Oral, Vol. 1', 'Obtener un Si', '5JwZwNT0SyOZlErdpvdEg3', 199173, False, 'Shakira', 4),
#  ('Shakira', 'Fijación Oral, Vol. 1', 'Dia Especial (feat. Gustavo Cerati)', '1XyRT1VeLaJs5rEJA3rMO9', 262666, False, 'Shakira, Gustavo Cerati', 5),
#  ('Shakira', 'Fijación Oral, Vol. 1', 'Escondite Ingles', '6FIa32QgkH62pbe4yX5Sgk', 186866, False, 'Shakira', 6),
#  ('Shakira', 'Fijación Oral, Vol. 1', 'No (feat. Gustavo Cerati)', '0J6dOwflFSy3h1AoKmkqKc', 285040, False, 'Shakira, Gustavo Cerati', 7),
#  ('Shakira', 'Fijación Oral, Vol. 1', 'Las de la Intuición', '3uU6dqBjVKRTPis0RrTaT4', 220666, False, 'Shakira', 8),
#  ('Shakira', 'Fijación Oral, Vol. 1', 'Dia de Enero', '0OEBOJhSObnFuHuasXdt52', 173133, False, 'Shakira', 9),
#  ('Shakira', 'Fijación Oral, Vol. 1', 'Lo Imprescindible', '5sQi44U78b4HJT4KgyT1Ub', 234866, False, 'Shakira', 10),
#  ('Shakira', 'Fijación Oral, Vol. 1', 'La Pared - Versión Acústica', '5u4QS9JQtNetXX6DfQ6TGF', 159066, False, 'Shakira', 11),
#  ('Shakira', 'Fijación Oral, Vol. 1', 'La Tortura (feat. Alejandro Sanz) - Shaketon Remix', '3FsGjnnVi70WRUHOmopafn', 192093, False, 'Shakira, Alejandro Sanz', 12),
#  ('Shakira', 'Servicio De Lavandería', 'Suerte (Whenever, Wherever)', '1YIoEGlYIrlir1FOdWmSe8', 194733, False, 'Shakira', 1),
#  ('Shakira', 'Servicio De Lavandería', 'Underneath Your Clothes', '6biR1gMwcN71SDt3Eh4eEu', 224426, False, 'Shakira', 2),
#  ('Shakira', 'Servicio De Lavandería', 'Te Aviso, Te Anuncio (Tango)', '6IIvQrGLkX6ZEABLPqyi7C', 222866, False, 'Shakira', 3),
#  ('Shakira', 'Servicio De Lavandería', 'Que Me Quedes Tú', '656yISUj1xcGthQHLC3iT5', 286933, False, 'Shakira', 4),
#  ('Shakira', 'Servicio De Lavandería', 'Rules', '2KB42Lvoav7uKtFSq5F6ZH', 219426, False, 'Shakira', 5),
#  ('Shakira', 'Servicio De Lavandería', 'The One', '56DUFNjNTxc243GLRLL0or', 222533, False, 'Shakira', 6),
#  ('Shakira', 'Servicio De Lavandería', 'Ready for the Good Times', '5tE1eHe1mxKJpqyzhYvyNE', 253226, False, 'Shakira', 7),
#  ('Shakira', 'Servicio De Lavandería', 'Fool', '1t9ZjhlzhGBtXsoaORZU3z', 230066, False, 'Shakira', 8),
#  ('Shakira', 'Servicio De Lavandería', 'Te Dejo Madrid', '0IESLhxv5iqXvMH5mm3z88', 187333, False, 'Shakira', 9),
#  ('Shakira', 'Servicio De Lavandería', 'Poem to a Horse', '1qpgdHfBm98SllC8mkaQwn', 246693, False, 'Shakira', 10),
#  ('Shakira', 'Servicio De Lavandería', 'Eyes Like Yours (Ojos Así)', '2Z0B1K4oP5s3xoFcCbDm4T', 236426, False, 'Shakira', 11),
#  ('Shakira', 'Servicio De Lavandería', 'Whenever, Wherever', '0RJWhctsc1G1Hg3Ov2th7x', 197026, False, 'Shakira', 12),
#  ('Shakira', 'Servicio De Lavandería', 'Objection (Tango)', '2N1vJgOptB5T0eqXaOAsaZ', 222960, False, 'Shakira', 13),
#  ('Shakira', 'Donde Estan Los Ladrones', 'Ciega, Sordomuda', '7jxHeJLVpnP7S08JFF4GBi', 267826, False, 'Shakira', 1),
#  ('Shakira', 'Donde Estan Los Ladrones', 'Si Te Vas', '7Apo6o7oxgFyXaSmdx6NHN', 210266, False, 'Shakira', 2),
#  ('Shakira', 'Donde Estan Los Ladrones', 'Moscas en la Casa', '1j5NOlhczuiPnZdT6aovgY', 211906, False, 'Shakira', 3),
#  ('Shakira', 'Donde Estan Los Ladrones', 'No Creo', '4suenIuyqxZYV0VIjsbYrG', 232200, False, 'Shakira', 4),
#  ('Shakira', 'Donde Estan Los Ladrones', 'Inevitable', '78dbqYDvx6FOefROApu9w0', 192866, False, 'Shakira', 5),
#  ('Shakira', 'Donde Estan Los Ladrones', 'Octavo Día', '4g5ucHrtIEM4LrIbrLo8Oz', 271400, False, 'Shakira', 6),
#  ('Shakira', 'Donde Estan Los Ladrones', 'Que Vuelvas', '3DjXu9jBpV5lPbhHQVyPQd', 230800, False, 'Shakira', 7),
#  ('Shakira', 'Donde Estan Los Ladrones', 'Tú', '6ZEVQ2whiJvhjCNAOJ0DC3', 214133, False, 'Shakira', 8),
#  ('Shakira', 'Donde Estan Los Ladrones', 'Dónde Están los Ladrones', '2nSd3kBslXIbBAdrmqvKM6', 193066, False, 'Shakira', 9),
#  ('Shakira', 'Donde Estan Los Ladrones', 'Sombra de Ti', '6rROXfjFzQyH2w9FAiVkq7', 213760, False, 'Shakira', 10),
#  ('Shakira', 'Donde Estan Los Ladrones', 'Ojos Así', '4EDfdYJ7mqXRoWAqzF1PVO', 235733, False, 'Shakira', 11),
#  ('Shakira', 'Pies Descalzos', 'Estoy Aquí', '4M1lEbqPzlEw1JYWB6aE7K', 232466, False, 'Shakira', 1),
#  ('Shakira', 'Pies Descalzos', 'Antologia', '0KAqMRUSZwzG3dZLdDA4eH', 254240, False, 'Shakira', 2),
#  ('Shakira', 'Pies Descalzos', 'Un Poco de Amor', '6dwhYg12fOFw8aUrnCOOqC', 241466, False, 'Shakira', 3),
#  ('Shakira', 'Pies Descalzos', 'Quiero', '3o4qlkbRP4DSXl4NBrWULJ', 250240, False, 'Shakira', 4),
#  ('Shakira', 'Pies Descalzos', 'Te Necesito', '6nR1XJxwiZlsDMnOsdlh5m', 240226, False, 'Shakira', 5),
#  ('Shakira', 'Pies Descalzos', 'Vuelve', '74DGE82ZVx7VKCoMgbyKBD', 233866, False, 'Shakira', 6),
#  ('Shakira', 'Pies Descalzos', 'Te Espero Sentada', '3J93BR2ihQjDQ9n9AfYTqu', 204960, False, 'Shakira', 7),
#  ('Shakira', 'Pies Descalzos', 'Pies Descalzos, Sueños Blancos', '5yKQTwznar5I75UyYJ9CnR', 205800, False, 'Shakira', 8),
#  ('Shakira', 'Pies Descalzos', 'Pienso en Ti', '4I0y9VniZ7JlDYthP8Vpo9', 145840, False, 'Shakira', 9),
#  ('Shakira', 'Pies Descalzos', 'Donde Estas Corazon', '6IGvaQ4aFBjy66TdUurIiA', 231693, False, 'Shakira', 10),
#  ('Shakira', 'Pies Descalzos', 'Se Quiere, Se Mata', '31NNxg7WYqs1bgRSFXgCf8', 218333, False, 'Shakira', 11)]

# %%
def get_audio_features(track_id, token):
    url = f"https://api.spotify.com/v1/audio-features/{track_id}"
    headers = {
        "Authorization": f"Bearer {token}"
    }

    response = requests.get(url, headers=headers)
    
    if response.status_code == 200:
        data = response.json()
        return {
            "acousticness": data.get("acousticness"),
            "danceability": data.get("danceability"),
            "energy": data.get("energy"),
            "instrumentalness": data.get("instrumentalness"),
            "liveness": data.get("liveness"),
            "loudness": data.get("loudness"),
            "speechiness": data.get("speechiness"),
            "tempo": data.get("tempo"),
            "valence": data.get("valence"),
            "analysis_url": data.get("analysis_url"),
            "key": data.get("key"),
            "mode": data.get("mode"),
            "time_signature": data.get("time_signature")
        }
    else:
        return {}

def get_track_info(track_id, token):
    url = f"https://api.spotify.com/v1/tracks/{track_id}"
    headers = {
        "Authorization": f"Bearer {token}"
    }

    response = requests.get(url, headers=headers)
    
    if response.status_code == 200:
        data = response.json()
        return {
            "popularity": data.get("popularity"),
            "name": data.get("name"),
            "album": data.get("album", {}).get("name"),
            "artists": [artist.get("name") for artist in data.get("artists", [])]
        }
    else:
        return {}

# %%
##### Asegurarse de haber corrido la primera celda
##### Para tener token de Spotify

for track in tracks:
    features = get_audio_features(track.ID, token)
    track_info = get_track_info(track.ID, token)
    
    cursor.execute("""
        INSERT INTO Track_Features_2 (Nombre_Artista, Nombre_Album, Nombre_Track, ID, Duration_ms, Explicit, Artists, Track_Number,
                                    acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, valence, analysis_url, [key], mode, time_signature, popularity)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    """, (
        track.Nombre_Artista, track.Nombre_Album, track.Nombre_Track, track.ID, track.Duration_ms, track.Explicit, track.Artists, track.Track_Number,
        features.get("acousticness"), features.get("danceability"), features.get("energy"), features.get("instrumentalness"),
        features.get("liveness"), features.get("loudness"), features.get("speechiness"), features.get("tempo"),
        features.get("valence"), features.get("analysis_url"), features.get("key"), features.get("mode"), features.get("time_signature"),track_info.get("popularity")
    ))

conn.commit()
cursor.close()
conn.close()
